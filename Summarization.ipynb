# %% [markdown]
# <a href="https://colab.research.google.com/github/gargankush/NLP_Learning/blob/master/Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
import torch
# Out:
#      |████████████████████████████████| 778kB 2.8MB/s
#      |████████████████████████████████| 890kB 9.8MB/s
#      |████████████████████████████████| 1.1MB 17.6MB/s
#      |████████████████████████████████| 3.0MB 14.1MB/s
# ...

# %%
## SUMMARIZATION | Model Name: 'facebook/bart-large-cnn' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'facebook/bart-large-cnn'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "Market surveillance in FICC has undergone, and continues to undergo, significant change as a result of regulation, the evolution of market structure, and technological developments. This Spotlight Review considers these structural and technological changes, in particular the emergence of machine learning trading strategies, and sets out some of the challenges associated with these developments for surveillance teams in FICC markets. The review then examines the role of technology as a potential solution to these challenges, creating as it does opportunities to improve market surveillance through the application of machine learning. Market surveillance has been an area of regulatory focus over recent years. In particular, the UK’s Financial Conduct Authority (FCA) has focused on the need for firms to continue to improve surveillance in FICC markets and to enhance both the quality and number of suspicious trade submissions relating to FICC markets activity. Furthermore, in the current remote working context, maintaining robust surveillance and suspicious transaction and order reporting has been flagged as a regulatory priority. However, further enhancing FICC surveillance in increasingly fast moving, complex and data-driven markets is not a simple task. This paper draws on two key structural challenges surveillance teams face in FICC markets: namely data quality and availability, and the increasing sophistication of trading strategies and technologies deployed to support them. The amount of data available to surveillance functions has increased significantly in recent years, driven by regulatory reporting requirements and the proliferation of electronic trading. However, extrapolating signals from these data sets remains challenging given variances in the  accuracy, robustness, timeliness and consistency of such data, in particular across different FICC asset classes. Furthermore, growth in algorithmic trading, systematic investment strategies and the nascent adoption of machine learning in trading is materially increasing the speed and complexity of FICC markets. This combination of increased data and trading complexity, and the possibility of new market abuse risks emerging as a result of these developments, may drive the adoption of new, or the improvement of existing, surveillance techniques."

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)
# Out:
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ['Market surveillance in FICC has undergone, and continues to undergo, significant change. This Spotlight Review considers these structural and technological changes. It then examines the role of technology as a potential solution to these challenges.']

# %%
## SUMMARIZATION | Model Name: 'facebook/bart-large-xsum' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'facebook/bart-large-xsum'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "Market surveillance in FICC has undergone, and continues to undergo, significant change as a result of regulation, the evolution of market structure, and technological developments. This Spotlight Review considers these structural and technological changes, the emergence of machine learning trading strategies, and sets out some of the challenges associated with these developments for surveillance teams in FICC markets. The review then examines the role of technology as a potential solution to these challenges, creating as it does opportunities to improve market surveillance through the application of machine learning. Market surveillance has been an area of regulatory focus over recent years. In particular, the UK’s Financial Conduct Authority (FCA) has focused on the need for firms to continue to improve surveillance in FICC markets and to enhance both the quality and number of suspicious trade submissions relating to FICC markets activity. Furthermore, in the current remote working context, maintaining robust surveillance and suspicious transaction and order reporting has been flagged as a regulatory priority. However, further enhancing FICC surveillance in increasingly fast moving, complex and data-driven markets is not a simple task. This paper draws on two key structural challenges surveillance teams face in FICC markets: namely data quality and availability, and the increasing sophistication of trading strategies and technologies deployed to support them. The amount of data available to surveillance functions has increased significantly in recent years, driven by regulatory reporting requirements and the proliferation of electronic trading. However, extrapolating signals from these data sets remains challenging given variances in the  accuracy, robustness, timeliness and consistency of such data, in particular across different FICC asset classes. Furthermore, growth in algorithmic trading, systematic investment strategies and the nascent adoption of machine learning in trading is materially increasing the speed and complexity of FICC markets. This combination of increased data and trading complexity, and the possibility of new market abuse risks emerging as a result of these developments, may drive the adoption of new, or the improvement of existing, surveillance techniques."

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)
# Out:
# ...
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-xsum and are newly initialized: ['final_logits_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ["A Spotlight Review into the role of machine learning in financial markets surveillance, published by the UK’s Financial Conduct Authority (FCA) and carried out by the Bank of England's Office of the Chief Inspector of Markets (Ombudsman), looks at some of the challenges and opportunities faced by market surveillance teams."]

# %%
## SUMMARIZATION | Model Name: 'sshleifer/distilbart-cnn-12-6' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'sshleifer/distilbart-cnn-12-6'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "Market surveillance in FICC has undergone, and continues to undergo, significant change as a result of regulation, the evolution of market structure, and technological developments. This Spotlight Review considers these structural and technological changes, the emergence of machine learning trading strategies, and sets out some of the challenges associated with these developments for surveillance teams in FICC markets. The review then examines the role of technology as a potential solution to these challenges, creating as it does opportunities to improve market surveillance through the application of machine learning. Market surveillance has been an area of regulatory focus over recent years. In particular, the UK’s Financial Conduct Authority (FCA) has focused on the need for firms to continue to improve surveillance in FICC markets and to enhance both the quality and number of suspicious trade submissions relating to FICC markets activity. Furthermore, in the current remote working context, maintaining robust surveillance and suspicious transaction and order reporting has been flagged as a regulatory priority. However, further enhancing FICC surveillance in increasingly fast moving, complex and data-driven markets is not a simple task. This paper draws on two key structural challenges surveillance teams face in FICC markets: namely data quality and availability, and the increasing sophistication of trading strategies and technologies deployed to support them. The amount of data available to surveillance functions has increased significantly in recent years, driven by regulatory reporting requirements and the proliferation of electronic trading. However, extrapolating signals from these data sets remains challenging given variances in the  accuracy, robustness, timeliness and consistency of such data, in particular across different FICC asset classes. Furthermore, growth in algorithmic trading, systematic investment strategies and the nascent adoption of machine learning in trading is materially increasing the speed and complexity of FICC markets. This combination of increased data and trading complexity, and the possibility of new market abuse risks emerging as a result of these developments, may drive the adoption of new, or the improvement of existing, surveillance techniques."

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)
# Out:
# ...
# [' Market surveillance in FICC markets has undergone significant change as a result of regulation, the evolution of market structure and technological developments. The UK’s Financial Conduct Authority (FCA) has focused on the need for firms to continue to improve surveillance  in FicC markets. This Spotlight Review considers these structural and technological changes, the emergence of machine learning trading strategies, and sets out some of the challenges associated with these developments.']

# %%
## SUMMARIZATION | Model Name: 'yjernite/bart_eli5' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'yjernite/bart_eli5'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "Market surveillance in FICC has undergone, and continues to undergo, significant change as a result of regulation, the evolution of market structure, and technological developments. This Spotlight Review considers these structural and technological changes, the emergence of machine learning trading strategies, and sets out some of the challenges associated with these developments for surveillance teams in FICC markets. The review then examines the role of technology as a potential solution to these challenges, creating as it does opportunities to improve market surveillance through the application of machine learning. Market surveillance has been an area of regulatory focus over recent years. In particular, the UK’s Financial Conduct Authority (FCA) has focused on the need for firms to continue to improve surveillance in FICC markets and to enhance both the quality and number of suspicious trade submissions relating to FICC markets activity. Furthermore, in the current remote working context, maintaining robust surveillance and suspicious transaction and order reporting has been flagged as a regulatory priority. However, further enhancing FICC surveillance in increasingly fast moving, complex and data-driven markets is not a simple task. This paper draws on two key structural challenges surveillance teams face in FICC markets: namely data quality and availability, and the increasing sophistication of trading strategies and technologies deployed to support them. The amount of data available to surveillance functions has increased significantly in recent years, driven by regulatory reporting requirements and the proliferation of electronic trading. However, extrapolating signals from these data sets remains challenging given variances in the  accuracy, robustness, timeliness and consistency of such data, in particular across different FICC asset classes. Furthermore, growth in algorithmic trading, systematic investment strategies and the nascent adoption of machine learning in trading is materially increasing the speed and complexity of FICC markets. This combination of increased data and trading complexity, and the possibility of new market abuse risks emerging as a result of these developments, may drive the adoption of new, or the improvement of existing, surveillance techniques."

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)
# Out:
# ...
# [' Market surveillance in FICC markets is a very difficult task. It’s not just about keeping track of what people are doing, it’s about making sure that the rules and regulations are followed. The biggest challenge is how to make sure that they follow the rules and regulations. There are lots of different ways to do this, but there are also lots of different ways to get around them. For example, you can have an automated trading system (e.g. bots) that will take all the orders and send them to each other so that everyone else has to pay attention to every order and trade accordingly. You can also have algorithms that look for patterns in trades and try to predict which ones are going to be']

# %%
## SUMMARIZATION | Model Name: 'mrm8488/t5-base-finetuned-summarize-news' 
## Language: English | Model Architecture: T5

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'mrm8488/t5-base-finetuned-summarize-news'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "✏️ ADD PARAGRAPH HERE IN ENGLISH TO SUMMARIZE"

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)

# %%
## SUMMARIZATION | Model Name: 'sshleifer/distilbart-xsum-12-6' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'sshleifer/distilbart-xsum-12-6'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "✏️ ADD PARAGRAPH HERE IN ENGLISH TO SUMMARIZE"

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)

# %%
## SUMMARIZATION | Model Name: 'airKlizz/bart-large-multi-combine-wiki-news' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'airKlizz/bart-large-multi-combine-wiki-news'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "✏️ ADD PARAGRAPH HERE IN ENGLISH TO SUMMARIZE"

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)

# %%
## SUMMARIZATION | Model Name: 'WikinewsSum/bart-large-multi-combine-wiki-news' 
## Language: English | Model Architecture: BART

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

path = 'WikinewsSum/bart-large-multi-combine-wiki-news'

tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForSeq2SeqLM.from_pretrained(path)

text = "✏️ ADD PARAGRAPH HERE IN ENGLISH TO SUMMARIZE"

input_ids = tokenizer.encode(text, 
                            return_tensors="pt", 
                            add_special_tokens=True)
#⚙️decoding parameters⚙️
num_beams = 2
min_length = 30
max_length = 150
repetition_penalty = 2.5
length_penalty = 1.0
early_stopping = True

generated_ids = model.generate(input_ids=input_ids, 
                               num_beams=num_beams,
                               min_length=30, 
                               max_length=max_length, 
                               repetition_penalty=repetition_penalty, 
                               length_penalty=length_penalty, 
                               early_stopping=early_stopping)

summarize = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
print(summarize)
